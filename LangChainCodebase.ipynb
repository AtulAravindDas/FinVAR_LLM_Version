# %% [markdown]
# <a href="https://colab.research.google.com/github/AtulAravindDas/FinVAR_LLM_Version/blob/main/LangChainCodebase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain-openai langchain-core langgraph>0.2.27

# %%
import sys
sys.path.append('/content/drive/MyDrive/')

# %%
# !pip install sec-edgar-downloader

# %%
# !pip install pdfkit
# !apt-get install -y wkhtmltopdf
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   avahi-daemon geoclue-2.0 glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas iio-sensor-proxy
#   libavahi-core7 libavahi-glib1 libdaemon0 libevdev2 libgudev-1.0-0 libhyphen0
#   libinput-bin libinput10 libjson-glib-1.0-0 libjson-glib-1.0-common
#   libmbim-glib4 libmbim-proxy libmd4c0 libmm-glib0 libmtdev1 libnl-genl-3-200
#   libnotify4 libnss-mdns libproxy1v5 libqmi-glib5 libqmi-proxy libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5positioning5 libqt5printsupport5
#   libqt5qml5 libqt5qmlmodels5 libqt5quick5 libqt5sensors5 libqt5svg5
#   libqt5webchannel5 libqt5webkit5 libqt5widgets5 libsoup2.4-1
#   libsoup2.4-common libudev1 libwacom-bin libwacom-common libwacom9 libwoff1
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
# ...

# %%
# !pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 28.1 MB/s eta 0:00:00
# ...

# %%
import ipywidgets as widgets
from IPython.display import clear_output
import plotly.io as pio
pio.renderers.default = 'colab'

# %%
from llm_initializer import LLMInitializer
from fmp_data_extract import FMPDataExtractor
from risk_section_extractor import RiskSectionExtractor
from context_query_builder import ContextQueryBuilder
from output_visualizer import OutputVisualizer
llm_initializer=LLMInitializer()
model=llm_initializer.get_model()
ticker=input("Enter ticker:")
fmp_extractor=FMPDataExtractor(ticker)
fmp_data=fmp_extractor.get_fmp_data()
risk_extractor=RiskSectionExtractor(ticker)
risk_data=risk_extractor.extract_risk_sections()
context_builder=ContextQueryBuilder(ticker,fmp_data,[risk_data[0],risk_data[1]])
print(context_builder.generate_context())
# Out:
# Enter ticker:MS
# Essential keys for 0000895421 dict_keys(['cik', 'entityType', 'sic', 'sicDescription', 'ownerOrg', 'insiderTransactionForOwnerExists', 'insiderTransactionForIssuerExists', 'name', 'tickers', 'exchanges', 'ein', 'lei', 'description', 'website', 'investorWebsite', 'category', 'fiscalYearEnd', 'stateOfIncorporation', 'stateOfIncorporationDescription', 'addresses', 'phone', 'flags', 'formerNames', 'filings'])
# Saved: 10-K.pdf
# TOC found on page 2
# Found line: Risk Factors
# Skipped non-digit line: 1A
# Start page number found: 13
# End page of Risk Factors section: 25
# 13
# 25
# Saved Risk Factors section as Risk_Factors.pdf
# TOC found on page 2
# Found line: Quantitative and Qualitative Disclosures about
# Page number found: 55
# Found line: Financial Statements and Supplementary Data
# [8, 76]
# Chosen end page: 76
# 55
# 76
# Saved QQDR section as QQDR_Factors.pdf
# Company Name: Morgan Stanley
#         Ticker: MS
# ...

# %%
from llm_initializer import LLMInitializer
from fmp_data_extract import FMPDataExtractor
from risk_section_extractor import RiskSectionExtractor
from context_query_builder import ContextQueryBuilder
from output_visualizer import OutputVisualizer
llm_initializer=LLMInitializer()
model=llm_initializer.get_model()
ticker=input("Enter ticker:")
fmp_extractor=FMPDataExtractor(ticker)
fmp_data=fmp_extractor.get_fmp_data()
risk_extractor=RiskSectionExtractor(ticker)
risk_data=risk_extractor.extract_risk_sections()
context_builder=ContextQueryBuilder(ticker,fmp_data,[risk_data[0],risk_data[1]])
formatted_prompt=context_builder.prompt_creation()
result=llm_initializer.invoke_model(formatted_prompt)
clear_output(wait=True)
print(result.content)

# %%
fmp_data
